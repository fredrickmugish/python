# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import PIL
import pathlib

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,Dense,Dropout, Flatten,Activation, BatchNormalization,MaxPooling2D
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.callbacks import EarlyStopping


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2023-12-15 21:32:25.258556: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-15 21:32:25.973609: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-15 21:32:25.973696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-15 21:32:25.998400: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-15 21:32:26.560982: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-15 21:32:26.582928: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-15 21:32:35.094745: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data_dir = pathlib.Path('/home/mugisha/Desktop/Fruits/images/') 
print(data_dir)
list(data_dir.glob('*/*'))[:5]
# Out:
# /home/mugisha/Desktop/Fruits/images
# [PosixPath('/home/mugisha/Desktop/Fruits/images/grapes fruit/Image_26.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/grapes fruit/Image_19.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/grapes fruit/Image_1.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/grapes fruit/Image_20.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/grapes fruit/Image_14.jpg')]

# %%
mango = list(data_dir.glob('mango fruit/*'))
mango[:5]
# Out:
# [PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_26.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_19.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_1.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_20.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_10.JPG')]

# %%
PIL.Image.open(str(mango[8]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
kiwi = list(data_dir.glob('kiwi fruit/*'))
kiwi[:5]
# Out:
# [PosixPath('/home/mugisha/Desktop/Fruits/images/kiwi fruit/Image_26.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/kiwi fruit/Image_19.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/kiwi fruit/Image_37.JPG'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/kiwi fruit/Image_20.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/kiwi fruit/Image_14.jpg')]

# %%
PIL.Image.open(str(kiwi[8]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x727>

# %%
apple = list(data_dir.glob('apple fruit/*'))
banana = list(data_dir.glob('banana fruit/*'))
cherry = list(data_dir.glob('cherry fruit/*'))
chickoo = list(data_dir.glob('chickoo fruit/*'))
grapes = list(data_dir.glob('grapes fruit/*'))
orange = list(data_dir.glob('orange fruit/*'))
strawberry = list(data_dir.glob('strawberry fruit/*'))

# %%
fruit_images_dict = {
    'mango': list(data_dir.glob('mango fruit/*')),
    'kiwi': list(data_dir.glob('kiwi fruit/*')),
    'apple': list(data_dir.glob('apple fruit/*')),
    'banana': list(data_dir.glob('banana fruit/*')),
    'cherry': list(data_dir.glob('cherry fruit/*')),
    'chickoo': list(data_dir.glob('chickoo fruit/*')),
    'grapes': list(data_dir.glob('grapes fruit/*')),
    'orange': list(data_dir.glob('orange fruit/*')),
    'strawberry': list(data_dir.glob('strawberry fruit/*'))
}

fruit_labels_dict = {
    'mango': 0,
    'kiwi': 1,
    'apple': 2,
    'banana': 3,
    'cherry': 4,
    'chickoo': 5,
    'grapes': 6,
    'orange': 7,
    'strawberry': 8
}

# %%
fruit_images_dict['mango'][:5]
# Out:
# [PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_26.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_19.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_1.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_20.jpg'),
#  PosixPath('/home/mugisha/Desktop/Fruits/images/mango fruit/Image_10.JPG')]

# %%
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_CHANNELS = 3
X, Y = [], []

for fruit_name, images in fruit_images_dict.items():
    print(fruit_name)
    for image in images:
        img = cv2.imread(str(image))
        if isinstance(img,type(None)): 
            #print('image not found')
            continue
            
        elif ((img.shape[0] >= IMAGE_HEIGHT) and  (img.shape[1] >=IMAGE_WIDTH)):
            resized_img = cv2.resize(img,(IMAGE_WIDTH,IMAGE_HEIGHT))
            X.append(resized_img)
            Y.append(fruit_labels_dict[fruit_name])
        else:
            #print("Invalid Image")
            continue
# Out:
# mango
# kiwi
# apple
# libpng warning: iCCP: known incorrect sRGB profile
# banana
# cherry
# chickoo
# grapes
# orange
# strawberry

# %%
X = np.array(X)
Y = np.array(Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, test_size=0.1)
print(len(X_train),len(Y_train))
print(len(X_test),len(Y_test))

print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# 323 323
# 36 36
# (323, 128, 128, 3) (323,)
# (36, 128, 128, 3) (36,)

# %%
IMAGE_CHANNELS=3
model = Sequential([

Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)),
BatchNormalization(),
MaxPooling2D(pool_size=(2, 2)),
Dropout(0.25),

Conv2D(64, (3, 3), activation='relu'),
BatchNormalization(),
MaxPooling2D(pool_size=(2, 2)),
Dropout(0.25),

Conv2D(128, (3, 3), activation='relu'),
BatchNormalization(),
MaxPooling2D(pool_size=(2, 2)),
Dropout(0.25),

Flatten(),
Dense(512, activation='relu'),
BatchNormalization(),
Dropout(0.5),
Dense(1, activation='softmax'), 
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (Batch  (None, 126, 126, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 61, 61, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 28, 28, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
# 2023-12-15 22:21:14.978502: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 51380224 exceeds 10% of free system memory.
# 2023-12-15 22:21:15.020475: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 51380224 exceeds 10% of free system memory.
# 2023-12-15 22:21:15.048247: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 51380224 exceeds 10% of free system memory.
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 12942273 (49.37 MB)
# Trainable params: 12940801 (49.37 MB)
# Non-trainable params: 1472 (5.75 KB)
# _________________________________________________________________

# %%
history=model.fit(X_train, Y_train, epochs=45)
# Out:
# Epoch 1/45
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 2/45
# 11/11 [==============================] - 8s 702ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 3/45
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 4/45
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 5/45
# 11/11 [==============================] - 8s 723ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 6/45
# 11/11 [==============================] - 8s 710ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 7/45
# 11/11 [==============================] - 8s 696ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 8/45
# 11/11 [==============================] - 8s 717ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 9/45
# 11/11 [==============================] - 8s 705ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 10/45
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 11/45
# 11/11 [==============================] - 8s 698ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 12/45
# 11/11 [==============================] - 8s 709ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 13/45
# 11/11 [==============================] - 8s 741ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 14/45
# 11/11 [==============================] - 8s 703ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 15/45
# 11/11 [==============================] - 8s 708ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 16/45
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 17/45
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 18/45
# 11/11 [==============================] - 8s 691ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 19/45
# 11/11 [==============================] - 8s 694ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 20/45
# 11/11 [==============================] - 8s 731ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 21/45
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 22/45
# 11/11 [==============================] - 8s 693ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 23/45
# 11/11 [==============================] - 8s 727ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 24/45
# 11/11 [==============================] - 8s 729ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 25/45
# 11/11 [==============================] - 8s 754ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 26/45
# 11/11 [==============================] - 9s 786ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 27/45
# 11/11 [==============================] - 8s 732ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 28/45
# 11/11 [==============================] - 8s 688ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 29/45
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 30/45
# 11/11 [==============================] - 8s 676ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 31/45
# 11/11 [==============================] - 8s 688ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 32/45
# 11/11 [==============================] - 8s 690ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 33/45
# 11/11 [==============================] - 7s 673ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 34/45
# 11/11 [==============================] - 8s 682ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 35/45
# 11/11 [==============================] - 7s 670ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 36/45
# 11/11 [==============================] - 8s 677ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 37/45
# 11/11 [==============================] - 8s 682ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 38/45
# 11/11 [==============================] - 8s 689ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 39/45
# 11/11 [==============================] - 8s 684ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 40/45
# 11/11 [==============================] - 8s 680ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 41/45
# 11/11 [==============================] - 8s 696ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 42/45
# 11/11 [==============================] - 8s 700ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 43/45
# 11/11 [==============================] - 8s 690ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 44/45
# 11/11 [==============================] - 8s 691ms/step - loss: 0.0000e+00 - accuracy: 0.0991
# Epoch 45/45
# 11/11 [==============================] - 8s 707ms/step - loss: 0.0000e+00 - accuracy: 0.0991

# %%
model.evaluate(X_test,Y_test)
# Out:
# 2/2 [==============================] - 1s 26ms/step - loss: 0.0000e+00 - accuracy: 0.2222
# [0.0, 0.2222222238779068]

# %%
from sklearn.metrics import confusion_matrix , classification_report
y_pred = model.predict(X_test)
y_pred_classes = [0 if element < 0.5 else 1 for element in y_pred]

print("Classification Report: \n", classification_report(Y_test, y_pred_classes, zero_division=0))
# Out:
# 2/2 [==============================] - 0s 25ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.22      1.00      0.36         8
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         4
#            6       0.00      0.00      0.00         5
#            7       0.00      0.00      0.00         4
#
#     accuracy                           0.22        36
#    macro avg       0.03      0.12      0.05        36
# weighted avg       0.05      0.22      0.08        36

# %%
classes = ["mango","kiwi","apple","banana","cherry","chickoo","grapes","orange","strawberry"]
from PIL import Image
fileImage = Image.open("/home/mugisha/Desktop/Fruits/images/kiwi fruit/Image_1.png").convert("RGB").resize([IMAGE_WIDTH,IMAGE_HEIGHT],Image.LANCZOS)
image = np.array(fileImage)
myimage = image.reshape(1, IMAGE_WIDTH,IMAGE_HEIGHT,3)
# prepare pixel data
#myimage = myimage.astype('float32')
#myimage = myimage/255.
plt.figure(figsize = (4,2))
plt.imshow(image)

my_predicted_image = model.predict(myimage)
print(my_predicted_image)
if (my_predicted_image < 0.40):
    y_class=0
else:
    y_class=1
print("class:",y_class,"name=",classes[y_class])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[1.]]
# class: 1 name= kiwi

# %%
classes = ["mango","kiwi","apple","banana","cherry","chickoo","grapes","orange","strawberry"]
from PIL import Image
fileImage = Image.open("/home/mugisha/Desktop/Fruits/images/strawberry fruit/Image_9.jpg").convert("RGB").resize([IMAGE_WIDTH,IMAGE_HEIGHT],Image.LANCZOS)
image = np.array(fileImage)
myimage = image.reshape(1, IMAGE_WIDTH,IMAGE_HEIGHT,3)
# prepare pixel data
#myimage = myimage.astype('float32')
#myimage = myimage/255.
plt.figure(figsize = (4,2))
plt.imshow(image)

my_predicted_image = model.predict(myimage)
print(my_predicted_image)
if (my_predicted_image < 0.40):
    y_class=0
else:
    y_class=8
print("class:",y_class,"name=",classes[y_class])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [[1.]]
# class: 1 name= kiwi
